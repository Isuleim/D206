# %%
import pandas as pd

# %%
# Info of column names along with the number of non –null values in each column,Categorical DATA TYPES

# %%
df = pd.read_csv('CrashData_TestClean.csv') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33164 entries, 0 to 33163
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CrashNbr            33164 non-null  int64
#  1   UnitIdNbr           31692 non-null  float64
#  2   PersonIdNbr         33164 non-null  int64
#  3   IncidentYear        33164 non-null  int64
#  4   PropertyDamageInd   33164 non-null  object
#  5   FatalitiesNbr       33164 non-null  int64
#  6   InjuriesNbr         33164 non-null  int64
#  7   PedestriansNbr      33164 non-null  int64
#  8   AgeNbr              33164 non-null  int64
#  9   DOBYear             19694 non-null  float64
#  10  GenderCde           23170 non-null  object
#  11  InjuryClassCde      24107 non-null  object
#  12  PersonTypeENum      33164 non-null  int64
#  13  SafetyEquipmentCde  24017 non-null  object
# dtypes: float64(2), int64(8), object(4)
# memory usage: 3.5+ MB

# %%
df.shape
# Out:
# (33164, 14)

# %%
# Finding whether we have null values in the data
df.isna().sum()
# Out:
# CrashNbr                  0
# UnitIdNbr              1472
# PersonIdNbr               0
# IncidentYear              0
# PropertyDamageInd         0
# FatalitiesNbr             0
# InjuriesNbr               0
# PedestriansNbr            0
# AgeNbr                    0
# DOBYear               13470
# GenderCde              9994
# InjuryClassCde         9057
# PersonTypeENum            0
# SafetyEquipmentCde     9147
# dtype: int64

# %%
# EXAMINE THE DISTRIBUTION
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'CrashNbr'}>,
#         <AxesSubplot:title={'center':'UnitIdNbr'}>,
#         <AxesSubplot:title={'center':'PersonIdNbr'}>],
#        [<AxesSubplot:title={'center':'IncidentYear'}>,
#         <AxesSubplot:title={'center':'FatalitiesNbr'}>,
#         <AxesSubplot:title={'center':'InjuriesNbr'}>],
#        [<AxesSubplot:title={'center':'PedestriansNbr'}>,
#         <AxesSubplot:title={'center':'AgeNbr'}>,
#         <AxesSubplot:title={'center':'DOBYear'}>],
#        [<AxesSubplot:title={'center':'PersonTypeENum'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.dropna()
# Out:
#        CrashNbr  UnitIdNbr  PersonIdNbr  IncidentYear PropertyDamageInd  \
# 0             1        1.0            1          2015                 N
# 1             1        2.0            2          2015                 N
# 2             1        2.0            3          2015                 N
# 3             2        2.0            1          2015                 N
# 4             3        1.0            1          2015                 N
# ...         ...        ...          ...           ...               ...
# 33150      9968        2.0            6          2015                 N
# 33151      9969        1.0            1          2015                 N
# 33156      9969        2.0            6          2015                 N
# 33157      9970        1.0            1          2015                 N
# 33162      9970        2.0            6          2015                 N
#
#        FatalitiesNbr  InjuriesNbr  PedestriansNbr  AgeNbr  DOBYear GenderCde  \
# ...

# %%
df.isna().sum()
# Out:
# CrashNbr                  0
# UnitIdNbr              1472
# PersonIdNbr               0
# IncidentYear              0
# PropertyDamageInd         0
# FatalitiesNbr             0
# InjuriesNbr               0
# PedestriansNbr            0
# AgeNbr                    0
# DOBYear               13470
# GenderCde              9994
# InjuryClassCde         9057
# PersonTypeENum            0
# SafetyEquipmentCde     9147
# dtype: int64

# %%
df.dropna()
# Out:
#        CrashNbr  UnitIdNbr  PersonIdNbr  IncidentYear PropertyDamageInd  \
# 0             1        1.0            1          2015                 N
# 1             1        2.0            2          2015                 N
# 2             1        2.0            3          2015                 N
# 3             2        2.0            1          2015                 N
# 4             3        1.0            1          2015                 N
# ...         ...        ...          ...           ...               ...
# 33150      9968        2.0            6          2015                 N
# 33151      9969        1.0            1          2015                 N
# 33156      9969        2.0            6          2015                 N
# 33157      9970        1.0            1          2015                 N
# 33162      9970        2.0            6          2015                 N
#
#        FatalitiesNbr  InjuriesNbr  PedestriansNbr  AgeNbr  DOBYear GenderCde  \
# ...

# %%
df.isna()
# Out:
#        CrashNbr  UnitIdNbr  PersonIdNbr  IncidentYear  PropertyDamageInd  \
# 0         False      False        False         False              False
# 1         False      False        False         False              False
# 2         False      False        False         False              False
# 3         False      False        False         False              False
# 4         False      False        False         False              False
# ...         ...        ...          ...           ...                ...
# 33159     False      False        False         False              False
# 33160     False      False        False         False              False
# 33161     False      False        False         False              False
# 33162     False      False        False         False              False
# 33163     False      False        False         False              False
#
#        FatalitiesNbr  InjuriesNbr  PedestriansNbr  AgeNbr  DOBYear  GenderCde  \
# ...

# %%
df.isna().sum()
# Out:
# CrashNbr                  0
# UnitIdNbr              1472
# PersonIdNbr               0
# IncidentYear              0
# PropertyDamageInd         0
# FatalitiesNbr             0
# InjuriesNbr               0
# PedestriansNbr            0
# AgeNbr                    0
# DOBYear               13470
# GenderCde              9994
# InjuryClassCde         9057
# PersonTypeENum            0
# SafetyEquipmentCde     9147
# dtype: int64

# %%
new_df = df.dropna()

# %%
new_df.isna().sum()
# Out:
# CrashNbr              0
# UnitIdNbr             0
# PersonIdNbr           0
# IncidentYear          0
# PropertyDamageInd     0
# FatalitiesNbr         0
# InjuriesNbr           0
# PedestriansNbr        0
# AgeNbr                0
# DOBYear               0
# GenderCde             0
# InjuryClassCde        0
# PersonTypeENum        0
# SafetyEquipmentCde    0
# dtype: int64

# %%
#export prepared dataset
new_df.to_csv('CleanedData101.csv', index = False)

# %%
new_df.to_csv("CleanedData101")
